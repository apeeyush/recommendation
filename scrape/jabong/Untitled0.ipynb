# %%
import pandas as pd

df = pd.read_csv('22/transformedData')
df.describe
# Out:
# <bound method DataFrame.describe of                                                     url      brand  \
# 0     http://www.jabong.com/enamor-Yellow-Non-Wired-...     Enamor
# 1     http://www.jabong.com/enamor-Multi-Non-Wired-P...     Enamor
# 2     http://www.jabong.com/enamor-Red-Padded-Bra-84...     Enamor
# 3     http://www.jabong.com/enamor-Multi-Panty-84131...     Enamor
# 4     http://www.jabong.com/melange-Cotton-White-Kur...    Melange
# 5     http://www.jabong.com/melange-Viscose-Red-Kurt...    Melange
# 6     http://www.jabong.com/hypno-tex-Georgette-Grey...  Hypno Tex
# 7     http://www.jabong.com/hypno-tex-Net-Orange-Emb...  Hypno Tex
# 8     http://www.jabong.com/hypno-tex-Net-Green-Embr...  Hypno Tex
# 9     http://www.jabong.com/hypno-tex-Georgette-Pink...  Hypno Tex
# 10    http://www.jabong.com/hypno-tex-Georgette-Crea...  Hypno Tex
# 11    http://www.jabong.com/hypno-tex-Net-Green-Embr...  Hypno Tex
# ...
